# %%
from fastai.vision.all import *
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-5635efd54484> in <module>
# ----> 1 from fastai.vision.all import *
#
# ~/.local/lib/python3.8/site-packages/fastai/vision/all.py in <module>
# ----> 1 from . import models
#       2 from ..basics import *
#       3 from ..callback.all import *
#       4 from .augment import *
#       5 from .core import *
#
# ~/.local/lib/python3.8/site-packages/fastai/vision/models/__init__.py in <module>
#       1 from . import xresnet
# ----> 2 from . import unet
#       3 from .tvm import *
#
# ~/.local/lib/python3.8/site-packages/fastai/vision/models/unet.py in <module>
#       5 # Cell
#       6 from ...torch_basics import *
# ----> 7 from ...callback.hook import *
#       8
#       9 # Cell
#
# ~/.local/lib/python3.8/site-packages/fastai/callback/hook.py in <module>
#       5
#       6 # Cell
# ...
